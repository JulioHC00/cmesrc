# %%
import sys
sys.path.append('../')

from src.cmesrc.config import CMESRCV3_DB
import pandas as pd
import sqlite3

# %%
# Read json file into a dataframe
df = pd.read_json('../data/raw/DONKI/CME.json')

# %%
df[df["catalog"] == 'M2M_CATALOG']
# Out:
#                        activityID      catalog          startTime  \
# 0     2010-06-13T07:32:00-CME-001  M2M_CATALOG  2010-06-13T07:32Z
# 1     2010-06-20T03:18:00-CME-001  M2M_CATALOG  2010-06-20T03:18Z
# 2     2010-07-03T01:30:00-CME-001  M2M_CATALOG  2010-07-03T01:30Z
# 3     2010-07-08T22:30:00-CME-001  M2M_CATALOG  2010-07-08T22:30Z
# 4     2010-07-29T08:24:00-CME-001  M2M_CATALOG  2010-07-29T08:24Z
# ...                           ...          ...                ...
# 2795  2018-08-02T10:00:00-CME-001  M2M_CATALOG  2018-08-02T10:00Z
# 2796  2018-08-11T12:09:00-CME-001  M2M_CATALOG  2018-08-11T12:09Z
# 2797  2018-08-19T07:54:00-CME-001  M2M_CATALOG  2018-08-19T07:54Z
# 2798  2018-08-20T21:24:00-CME-001  M2M_CATALOG  2018-08-20T21:24Z
# 2799  2018-09-27T04:54:00-CME-001  M2M_CATALOG  2018-09-27T04:54Z
#
#      sourceLocation  activeRegionNum  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# ...
